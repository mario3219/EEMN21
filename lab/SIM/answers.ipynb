# %% [markdown]
# # Q1 What shape does the velocity profile have?
#
# ![velocity profile.png](<attachment:velocity profile.png>)

# %% [markdown]
# # Q2 Does the velocity profile change along the channel length?
# I made a cut line through the middle of the channel, and plotted y-axis on speed, and x-axis as x ie channel length
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Q3 How does the pressure change along the channel length?
# I made a new surface plot using expression p instead of u, resulting in a pressure map
#
# ![image.png](attachment:image.png)
#
# I also used the cut lines from before to plot the pressure profiles
#
# ![image-2.png](attachment:image-2.png)
#
# # Q4 How does the pressure depend on the distance from the walls?
#
# ![image-3.png](attachment:image-3.png)
#
# This is a confusing result. Why is the pressure change along the width so erratic? (Probably because it is very zoomed in the y-scale, making a linear plot look noisy)
#
# # Q5 How does the pressure drop along the channel scale with viscosity?
#
# ![image-4.png](attachment:image-4.png)
#
# Linearly, higher viscosity leads to higher drop per metre. The startoff pressure changes in each iteration because we set an absolute velocity as 1mm/s, and the pressure has to change accordingly for this to be upheld.
#
# # Q6 How does increasing the diffusion constant by a factor of 10 affect the concentration profile?
#
# ![image-5.png](attachment:image-5.png)
#
# The horizontal cut-line is placed in the middle of the channel. According to the plot, higher diffusion constant leads to lower concentrations in the middle of the channel, meaning that higher diffusion leads to moore diffusion through the channel.
#
# # Q7 Why is the pressure gradient steeper in the main channel as compared to the central inlet?
#
# ![image-6.png](attachment:image-6.png)
#
# My guess: The path from central inlet to main is rather small, where in the intersection all other inlets meet, summarizing pressures. The main channel travels in one geometry to zero pressure, therefore a steeper drop.
#
# In conclusion: the central inlet ends at non-zero pressure, main ends at zero pressure.
#
# # Time-dependent simulations
# My results after cutting the geometry, changing parameters for the new geometry, and adding a new time-dependent study.
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# # Particle Tracing
# These are the results from my particle tracing
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# # Dispersion
# Results from dispersion
#
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
